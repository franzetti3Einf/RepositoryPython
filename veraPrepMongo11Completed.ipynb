# %% [markdown]
# Caricare in un dataframe Pandas la collection "sales" del database "sample_supplies" che si può recuperare tramite la stringa di connessione
#
# "mongodb://webUser:xxx123xxx@cluster0-shard-00-00.algwo.mongodb.net:27017,cluster0-shard-00-01.algwo.mongodb.net:27017,cluster0-shard-00-02.algwo.mongodb.net:27017/?ssl=true&replicaSet=atlas-am4cb3-shard-0&authSource=admin&retryWrites=true&w=majority"

# %% [markdown]
# **Una volta caricata la collection nel dataframe pandas, scrivere il codice necessario per inserire i record del dataframe in una collection presente nel proprio database. Chiamare la nuova collection "vendite".**
#
# **A questo punto scrivere le istruzioni per:**

# %%
import pymongo
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb://Emanuele-Visioli:EMAnuele25102004@cluster0-shard-00-00.x7fma.mongodb.net:27017,cluster0-shard-00-01.x7fma.mongodb.net:27017,cluster0-shard-00-02.x7fma.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-566dc8-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.sample_supplies

# %%
'''result=db.sales.find_one()
result'''
# Out:
# 'result=db.sales.find_one()\nresult'

# %%
df=pd.DataFrame(list(db.sales.find()))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 4650  5bd761deae323e45a93ce33e 2015-11-25 21:06:13.187
# 4651  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 4652  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 4653  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': ['writing', 'office'...       Seattle
# 1     [{'name': 'printer paper', 'tags': ['office', ...      New York
# 2     [{'name': 'pens', 'tags': ['writing', 'office'...        Denver
# ...

# %% [markdown]
# ----------------------------------

# %%
client = pymongo.MongoClient("mongodb://Loi:IIeee1mm@cluster0-shard-00-00.ujobt.mongodb.net:27017,cluster0-shard-00-01.ujobt.mongodb.net:27017,cluster0-shard-00-02.ujobt.mongodb.net:27017/myFirstDatabase?ssl=true&replicaSet=atlas-qtdhit-shard-0&authSource=admin&retryWrites=true&w=majority")
db2 = client.Loi

# %%
db2.vendite_.insert_many(df.to_dict('records'))

# %%
db2.vendite7.insert_many(df.to_dict('records'))

# %%
df = pd.DataFrame(list(db2.vendite_.find()))

# %%
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93cd070 2013-10-28 04:30:35.709
# 1     5bd761dcae323e45a93cd024 2013-09-20 14:23:01.776
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93cd002 2015-04-18 03:33:09.638
# 4     5bd761dcae323e45a93ccffd 2015-07-27 20:05:46.464
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce350 2014-02-14 06:48:14.624
# 4650  5bd761deae323e45a93ce2ff 2013-05-21 03:44:24.287
# 4651  5bd761deae323e45a93ce2c1 2017-11-15 17:12:03.124
# 4652  5bd761deae323e45a93ce2c8 2016-12-05 19:53:34.335
# 4653  5bd761deae323e45a93ce318 2014-12-27 16:58:01.050
#
#                                                   items storeLocation  \
# 0     [{'name': 'binder', 'tags': ['school', 'genera...        Denver
# 1     [{'name': 'notepad', 'tags': ['office', 'writi...        London
# 2     [{'name': 'laptop', 'tags': ['electronics', 's...        Denver
# ...

# %% [markdown]
# -------------------------------------------

# %% [markdown]
# **1. cancellare tutti i document relativi al negozio di San Diego**

# %%
result = db2.vendite_.delete_many({"storeLocation":'San Diego'})
result.deleted_count
# Out:
# 0

# %%
df1 = pd.DataFrame(list(db2.vendite_.find()))
df1
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 4650  5bd761deae323e45a93ce33e 2015-11-25 21:06:13.187
# 4651  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 4652  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 4653  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': ['writing', 'office'...       Seattle
# 1     [{'name': 'printer paper', 'tags': ['office', ...      New York
# 2     [{'name': 'pens', 'tags': ['writing', 'office'...        Denver
# ...

# %% [markdown]
# **2. invecchiare i clienti di 8 anni**

# %%
result = db2.vendite_.update_many({},{ "$inc": { "customer.age": 8}})
result.modified_count
# Out:
# 4654

# %%
df1 = pd.DataFrame(list(db2.vendite_.find()))
df1
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93cd070 2013-10-28 04:30:35.709
# 1     5bd761dcae323e45a93cd024 2013-09-20 14:23:01.776
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93cd002 2015-04-18 03:33:09.638
# 4     5bd761dcae323e45a93ccffd 2015-07-27 20:05:46.464
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce350 2014-02-14 06:48:14.624
# 4650  5bd761deae323e45a93ce2ff 2013-05-21 03:44:24.287
# 4651  5bd761deae323e45a93ce2c1 2017-11-15 17:12:03.124
# 4652  5bd761deae323e45a93ce2c8 2016-12-05 19:53:34.335
# 4653  5bd761deae323e45a93ce318 2014-12-27 16:58:01.050
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': ['writing', 'office'...        Denver
# 1     [{'name': 'notepad', 'tags': ['office', 'writi...        London
# 2     [{'name': 'pens', 'tags': ['writing', 'office'...        Denver
# ...

# %% [markdown]
# **3. cancellare tutti i tag 'stationary'**

# %%
result = db2.vendite_.find({"items.tags": "stationary"})
df = pd.DataFrame(list(result))
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
result = db2.vendite_.update_many({},{"$pull" : {"items" :{ "tags": "stationary"}}})
result.modified_count
# Out:
# 4090

# %% [markdown]
# **4. eliminare tutti i document di clienti che hanno più di 80 anni e meno di 40**

# %%
result = db2.vendite_.find({'$or': [{"customer.age" : {'$gt' : 80 }} , {"customer.age" : {'$lt' : 40 }}]})
df = pd.DataFrame(list(result))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccffc 2015-11-12 12:06:07.052
# 1     5bd761dcae323e45a93cd0ff 2013-08-25 22:04:11.735
# 2     5bd761dcae323e45a93ccffd 2015-07-27 20:05:46.464
# 3     5bd761dcae323e45a93cd01f 2013-03-16 11:31:20.572
# 4     5bd761dcae323e45a93cd071 2015-06-10 10:15:04.205
# ...                        ...                     ...
# 1005  5bd761deae323e45a93ce303 2014-11-03 16:17:08.982
# 1006  5bd761deae323e45a93ce30b 2016-11-14 06:59:19.730
# 1007  5bd761deae323e45a93ce27f 2017-02-13 21:26:28.310
# 1008  5bd761deae323e45a93ce2bc 2015-11-06 00:15:27.205
# 1009  5bd761deae323e45a93ce33e 2015-11-25 21:06:13.187
#
#                                                   items storeLocation  \
# 0     [{'name': 'binder', 'tags': ['school', 'genera...        Denver
# 1     [{'name': 'notepad', 'tags': ['office', 'writi...       Seattle
# 2     [{'name': 'binder', 'tags': ['school', 'genera...        Denver
# ...

# %%
result = db2.vendite_.delete_many({'$or': [{"customer.age" : {'$gt' : 80 }} , {"customer.age" : {'$lt' : 40 }}]})
result.deleted_count
# Out:
# 1010

# %% [markdown]
# **5. calcolare il prezzo medio degli items**

# %%
result = db2.vendite_.aggregate([{"$unwind": "$items"},
                                {"$group": {"_id": "prezzo medio", "prezzoMedio": {"$avg":"$items.price"}}}])

df = pd.DataFrame(list(result))
df
# Out:
#             _id                          prezzoMedio
# 0  prezzo medio  172.5072270909555007232196035054880

# %% [markdown]
# **6. modificare le mail che hanno il dominio .mz in .com**

# %%
result = db2.vendite_.find({"customer.email" : {'$regex' : ".mz$" }})
df = pd.DataFrame(list(result))
df

# %%
result = db2.vendite_.update_many({ "customer.email": { "$regex": ".mz$" } },
                                  [{"$set": { "customer.email": {"$replaceOne": { "input": "$email", "find": ".mz", "replacement": ".com" }}}}])
result.modified_count
# Out:
# 21

# %% [markdown]
# **7. modificare il tag 'school' in 'education'**

# %%
result = db2.vendite_.find({ "items": {"tags":"school" } })
df1 = pd.DataFrame(list(result))
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
result = db2.venditeCopy2.find({"items.tags": "education"})
df = pd.DataFrame(list(result))
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
result =db2.s1.update_many(
   {
    
     "items": { "$elemMatch": { "tags": "school" } }
   },
   { "$set": { "items.$[item].tags" : "education" } }
)
result.modified_count
# Out:
# 0

# %%
result = db2.s2.update_many({ "items.tags": "school"},
                                    { "$set":{"items.$.tags": "education"}})
result.modified_count
# Out:
# 4386

# %%
result = db2.j.update_many({ "items.tags": { "$regex": "school" } },
                                  [{"$set": { "items.tags": {"$replaceOne": { "input": "$tags", "find": "school", "replacement": "education" }}}}])
result.modified_count
# Out:
# 4386

# %%
db2.vendite_.aggregate([{"$out": "j"}])

# %%
df = pd.DataFrame(list(db2.j.find()))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93cd070 2013-10-28 04:30:35.709
# 1     5bd761dcae323e45a93cd024 2013-09-20 14:23:01.776
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93cd002 2015-04-18 03:33:09.638
# 4     5bd761dcae323e45a93ccffd 2015-07-27 20:05:46.464
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce350 2014-02-14 06:48:14.624
# 4650  5bd761deae323e45a93ce2ff 2013-05-21 03:44:24.287
# 4651  5bd761deae323e45a93ce2c1 2017-11-15 17:12:03.124
# 4652  5bd761deae323e45a93ce2c8 2016-12-05 19:53:34.335
# 4653  5bd761deae323e45a93ce318 2014-12-27 16:58:01.050
#
#                                                   items storeLocation  \
# 0     [{'name': 'binder', 'tags': None, 'price': 24....        Denver
# 1     [{'name': 'notepad', 'tags': None, 'price': 27...        London
# 2     [{'name': 'laptop', 'tags': None, 'price': 121...        Denver
# ...

# %%
result = db2.vendite_.update_many({ "items.tags": { "$regex": "school" } },
                                  [{"$set": { "items.tags": {"$replaceOne": { "input": "$tags", "find": "school", "replacement": "education" }}}}])
result.modified_count

# %%
result = db2.mycopy4.aggregate([{"$unwind": "$items"},
                             
                                ])

df = pd.DataFrame(list(result))
df
# Out:
#                             _id                saleDate  \
# 0      5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 1      5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2      5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 3      5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 4      5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# ...                         ...                     ...
# 25542  5bd761deae323e45a93ce301 2015-08-26 05:22:47.913
# 25543  5bd761deae323e45a93ce301 2015-08-26 05:22:47.913
# 25544  5bd761deae323e45a93ce301 2015-08-26 05:22:47.913
# 25545  5bd761deae323e45a93ce32e 2014-04-15 15:39:48.240
# 25546  5bd761deae323e45a93ce32e 2014-04-15 15:39:48.240
#
#                                                    items storeLocation  \
# 0      {'name': 'printer paper', 'tags': None, 'price...      New York
# 1      {'name': 'binder', 'tags': None, 'price': 23.3...      New York
# 2      {'name': 'envelopes', 'tags': None, 'price': 2...      New York
# ...

# %%
result = db2.mycopy4.update_many({ "items.tags": { "$regex": "school" } },
                                 [{"$set": { "items.tags": {"$replaceOne": { "input": "$tags", "find": "school", "replacement": "education" }}}}])

result.modified_count
# Out:
# 0

# %%
result =db2.mycopy4.update_many(
    { "items": "school" }, 
    { "$set": { "tags.$": "education" } }
)
result.modified_count
# Out:
# 0

# %%
result =db2.mycopy4.update_many(
  { "items.tags": { "$regex": "school" } },
  [{
    "$set": {
      "items.tags": {
        "$map": {
          "input": "$tags",
          "in": {
            "$replaceOne": {
             "input": "$$this",
              "find": "school",
              "replacement": "education"
            }
          }
        }
      }
    }
  }]
)
result.modified_count
# Out:
# 4525

# %%
result =db2.mycopy5.aggregate([
  {
    "$addFields":
      {
        "resultObject": { "$replaceAll": { "input": "$tags", "find": "school", "replacement": "education" } }
      }
  }
])

df = pd.DataFrame(list(result))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 4650  5bd761deae323e45a93ce33e 2015-11-25 21:06:13.187
# 4651  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 4652  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 4653  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': ['writing', 'office'...       Seattle
# 1     [{'name': 'printer paper', 'tags': ['office', ...      New York
# 2     [{'name': 'pens', 'tags': ['writing', 'office'...        Denver
# ...

# %%
df=pd.DataFrame(list(db2.mycopy4.find()))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 4649  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 4650  5bd761deae323e45a93ce33e 2015-11-25 21:06:13.187
# 4651  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 4652  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 4653  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': None, 'price': 75.21...       Seattle
# 1     [{'name': 'printer paper', 'tags': None, 'pric...      New York
# 2     [{'name': 'pens', 'tags': None, 'price': 26.64...        Denver
# ...

# %%
result =db2.Vendite.update_many(
  { URL: { $regex: /helloWorldt/ } },
  [{
    $set: { URL: {
      $replaceOne: { input: "$URL", find: "helloWorldt", replacement: "helloWorld" }
    }}
  }]
)
result.modified_count

# %%
result = db2.vendite_.find({ "items.tags": { "$regex": "education" } })
df1 = pd.DataFrame(list(result))
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# **8. aggiungere 7 anni alla data degli ordini**

# %%
import datetime

# %%
result=db2.vendite_.aggregate([
   {
      "$addFields": {
         "saleDate": {
            "$dateFromParts": {
               "year": { "$add": [{ "$year": "$saleDate" }, 7] },
               "month": { "$month": "$saleDate" },
               "day": { "$dayOfMonth": "$saleDate" },
               "hour": { "$hour": "$saleDate" },
               "minute": { "$minute": "$saleDate" },
               "second": { "$second": "$saleDate" },
               "millisecond": { "$millisecond": "$saleDate" }
            }
         }
      }
   }
])
df1 = pd.DataFrame(list(result))
df1
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2022-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2022-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2021-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2024-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2024-12-03 18:39:48.253
# ...                        ...                     ...
# 3639  5bd761deae323e45a93ce337 2021-04-29 05:00:20.567
# 3640  5bd761deae323e45a93ce33a 2023-12-22 15:24:27.219
# 3641  5bd761deae323e45a93ce361 2020-02-09 21:00:27.568
# 3642  5bd761deae323e45a93ce368 2022-04-22 08:31:40.113
# 3643  5bd761deae323e45a93ce369 2020-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'backpack', 'tags': None, 'price': 6...       Seattle
# 1     [{'name': 'binder', 'tags': None, 'price': 23....      New York
# 2     [{'name': 'laptop', 'tags': None, 'price': 121...        Denver
# ...

# %% [markdown]
# **9. trovare il prodotto venduto più costoso**

# %%
result = db2.vendite_.aggregate([
     {
    '$unwind': '$items',
    
  },                             

    { "$group": {
        "_id": "maxPrice ",
        "maxPrice": {
            "$max": "$items.price"
        },
        "customerdata": {
            "$push": {
                
                "email": "$customer.email",       
            }
        }
       }
    },
{
    
    '$unwind': '$maxPrice',
}


    ])
dbRes = pd.DataFrame(list(result))
dbRes
# Out:
#          _id maxPrice                                       customerdata
# 0  maxPrice   1599.49  [{'email': 'keigutip@vaw.tc'}, {'email': 'keig...

# %% [markdown]
# **10. eliminare dagli ordini tutti i prodotti "envelopes"**

# %%
result = db2.vendite7.find({"items.name": "envelopes"})
df = pd.DataFrame(list(result))
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame(list(db2.vendite_.find()))
df
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 3639  5bd761deae323e45a93ce337 2014-04-29 05:00:20.567
# 3640  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 3641  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 3642  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 3643  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'backpack', 'tags': None, 'price': 6...       Seattle
# 1     [{'name': 'binder', 'tags': None, 'price': 23....      New York
# 2     [{'name': 'laptop', 'tags': None, 'price': 121...        Denver
# ...

# %%
result = db2.vendite7.delete_many({"items.name":'envelopes'})
result.deleted_count
# Out:
# 3086

# %%
df1 = pd.DataFrame(list(db2.vendite_.find()))
df1
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 1     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 2     5bd761dcae323e45a93cd017 2015-01-11 10:46:32.673
# 3     5bd761dcae323e45a93cd01d 2014-07-24 02:47:51.251
# 4     5bd761dcae323e45a93cd0c4 2013-08-28 08:43:34.725
# ...                        ...                     ...
# 1563  5bd761deae323e45a93ce2c1 2017-11-15 17:12:03.124
# 1564  5bd761deae323e45a93ce314 2015-05-05 19:25:09.576
# 1565  5bd761deae323e45a93ce33e 2015-11-25 21:06:13.187
# 1566  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 1567  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'pens', 'tags': ['writing', 'office'...        Denver
# 1     [{'name': 'notepad', 'tags': ['office', 'writi...        Denver
# 2     [{'name': 'notepad', 'tags': ['office', 'writi...       Seattle
# ...

# %% [markdown]
# **11. copiare la collection "vendite" nella collection "vendite_modificata"**

# %%
db2.vendite_.aggregate([{"$out": "mycopy"}])

# %%
db2.vendite_.aggregate([{"$out": "mycopy5"}])

# %%
df1 = pd.DataFrame(list(db2.mycopy.find()))
df1
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 3639  5bd761deae323e45a93ce337 2014-04-29 05:00:20.567
# 3640  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 3641  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 3642  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 3643  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'backpack', 'tags': None, 'price': 6...       Seattle
# 1     [{'name': 'binder', 'tags': None, 'price': 23....      New York
# 2     [{'name': 'laptop', 'tags': None, 'price': 121...        Denver
# ...

# %% [markdown]
# **12. eliminare la collection "vendite"**

# %%
db2.Vendite.drop()

# %%
df1 = pd.DataFrame(list(db2.Vendite.find()))
df1
# Out:
#                            _id                saleDate  \
# 0     5bd761dcae323e45a93ccff2 2015-07-25 07:20:29.804
# 1     5bd761dcae323e45a93ccffb 2015-11-16 22:02:34.415
# 2     5bd761dcae323e45a93ccff1 2014-08-18 04:37:26.849
# 3     5bd761dcae323e45a93ccfea 2017-06-22 09:54:14.185
# 4     5bd761dcae323e45a93ccfec 2017-12-03 18:39:48.253
# ...                        ...                     ...
# 3639  5bd761deae323e45a93ce337 2014-04-29 05:00:20.567
# 3640  5bd761deae323e45a93ce33a 2016-12-22 15:24:27.219
# 3641  5bd761deae323e45a93ce361 2013-02-09 21:00:27.568
# 3642  5bd761deae323e45a93ce368 2015-04-22 08:31:40.113
# 3643  5bd761deae323e45a93ce369 2013-03-20 18:17:19.463
#
#                                                   items storeLocation  \
# 0     [{'name': 'backpack', 'tags': None, 'price': 6...       Seattle
# 1     [{'name': 'binder', 'tags': None, 'price': 23....      New York
# 2     [{'name': 'laptop', 'tags': None, 'price': 121...        Denver
# ...

# %%
result = db2.Vendite.aggregate([
    { "$group": {
        "_id": "l'ètà massima è ",
        "maxAge": {
            "$max": "$customer.age"
        },
        "customerdata": {
            "$push": {
                "age": "$customer.age",
                "email": "$customer.email",       
            }
        }
       }
    },
{
    '$unwind': '$customerdata'
},{
    "$match" : {"$expr": {"$eq":["$customerdata.age","$maxAge"]}}
}

    ])
dbRes = pd.DataFrame(list(result))
dbRes
# Out:
#                  _id  maxAge                                  customerdata
# 0   l'ètà massima è       80    {'age': 80, 'email': 'mepzege@egwuuvo.py'}
# 1   l'ètà massima è       80     {'age': 80, 'email': 'lagumsu@omanef.hk'}
# 2   l'ètà massima è       80          {'age': 80, 'email': 'cutki@gap.st'}
# 3   l'ètà massima è       80   {'age': 80, 'email': 'uhotag@tuffigzo.net'}
# 4   l'ètà massima è       80      {'age': 80, 'email': 'joiji@ivwanih.sh'}
# 5   l'ètà massima è       80    {'age': 80, 'email': 'vekjic@kanasdut.tw'}
# 6   l'ètà massima è       80          {'age': 80, 'email': 'uw@wirwoz.cz'}
# 7   l'ètà massima è       80  {'age': 80, 'email': 'geovfog@getdamlaw.lt'}
# 8   l'ètà massima è       80    {'age': 80, 'email': 'kadnud@difdukca.dk'}
# 9   l'ètà massima è       80          {'age': 80, 'email': 'it@noirle.io'}
# 10  l'ètà massima è       80           {'age': 80, 'email': 'rozec@il.mw'}
# ...
